# %%
 A = 12

# %%
A
# Out:
# 12

# %%
type(A)
# Out:
# int

# %%
B = 2.4

# %%
B
# Out:
# 2.4

# %%
type(B)
# Out:
# float

# %%
C = 'sparrow'

# %%
C
# Out:
# 'sparrow'

# %%
 type(C)
# Out:
# str

# %%
D = '400.9'

# %%
type (D)
# Out:
# str

# %%
E = 'dany is from nagpur'

# %%
E
# Out:
# 'dany is from nagpur'

# %%
type(E)
# Out:
# str

# %%
print (A+B)
# Out:
# 14.4

# %%
print (E)
# Out:
# dany is from nagpur

# %%
print ('today i am going outside')
# Out:
# today i am going outside

# %%
print (2000+4000)
# Out:
# 6000

# %%
lst = [23,5,78,45,67,3,7,89,100]

# %%
type(lst)
# Out:
# list

# %%
lst
# Out:
# [23, 5, 78, 45, 67, 3, 7, 89, 100]

# %%
len(lst)
# Out:
# 9

# %%
lst1 = ['sonu','monu','deep','tom']

# %%
lst1
# Out:
# ['sonu', 'monu', 'deep', 'tom']

# %%
len(lst1)
# Out:
# 4

# %%
lst
# Out:
# [23, 5, 78, 45, 67, 3, 7, 89, 100]

# %%
lst1
# Out:
# ['sonu', 'monu', 'deep', 'tom']

# %%
lst2 = ['sonu',23,'sparrow10',3.4,78,2000000000]

# %%
type(lst2)
# Out:
# list

# %%
len(lst2)
# Out:
# 6

# %%
lst2
# Out:
# ['sonu', 23, 'sparrow10', 3.4, 78, 2000000000]

# %%
lst1
# Out:
# ['sonu', 'monu', 'deep', 'tom']

# %%
lst
# Out:
# [23, 5, 78, 45, 67, 3, 7, 89, 100]

# %%
len(lst)
# Out:
# 9

# %%
# indexing start from 0

# %%
lst [7]
# Out:
# 89

# %%
lst [4]
# Out:
# 67

# %%
lst
# Out:
# [23, 5, 78, 45, 67, 3, 7, 89, 100]

# %%
lst[4] = 'runali'

# %%
lst
# Out:
# [23, 5, 78, 45, 'runali', 3, 7, 89, 100]

# %%
lst [3:6]
# Out:
# [45, 'runali', 3]

# %%
lst [2:]
# Out:
# [78, 45, 'runali', 3, 7, 89, 100]

# %%
lst [:6]
# Out:
# [23, 5, 78, 45, 'runali', 3]

# %%
lst [0:4]
# Out:
# [23, 5, 78, 45]

# %%
lst[:4]
# Out:
# [23, 5, 78, 45]

# %%
lst
# Out:
# [23, 5, 78, 45, 'runali', 3, 7, 89, 100]

# %%
lst [4] = 1000

# %%
lst
# Out:
# [23, 5, 78, 45, 1000, 3, 7, 89, 100]

# %%
nest = [11,32,[43,46]]

# %%
type (nest)
# Out:
# list

# %%
nest
# Out:
# [11, 32, [43, 46]]

# %%
len(nest)
# Out:
# 3

# %%
nest [2]
# Out:
# [43, 46]

# %%
nest [2] [1]
# Out:
# 46

# %%
nest1 = [3,5,8,[9,11,[20,'target']]]

# %%
nest1
# Out:
# [3, 5, 8, [9, 11, [20, 'target']]]

# %%
len (nest1)
# Out:
# 4

# %%
nest1 [3]
# Out:
# [9, 11, [20, 'target']]

# %%
nest1 [3] [2]
# Out:
# [20, 'target']

# %%
nest1 [3] [2] [1]
# Out:
# 'target'
